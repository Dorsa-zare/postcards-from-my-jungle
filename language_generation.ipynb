# %%
from openai import OpenAI
import os

# set key directly (temporary)
client = OpenAI(api_key="YOUR_API_KEY")

client = OpenAI()

response = client.responses.create(
    model="gpt-4.1-nano",
    input=[
        {
            "role": "developer",
            "content": "Invent a fictional jungle animal language. Output ONLY 16 short phrases."
        },
        {
            "role": "user",
            "content": "Rules: No real English words. 5-8 words per phrase. Soft sounds like m, n, l, r, sh. Use repetition."
        }
    ],
    temperature=1.2,
    max_output_tokens=200
)

print(response.output[0].content[0].text)
# Out:
# 1. Meli meli lua luna.
# 2. Nanu, rolla, ralu numa.
# 3. Shira shira pura puru.
# 4. Luma lumina nara naru.
# 5. Mura mura shalai shalai.
# 6. Nini, riri, lila lila.
# 7. Shala shala munu muna.
# 8. Nanu nara rura rur.
# 9. Lumini lumina sirri sirr.
# 10. Nelu nelu miri miri.
# 11. Rila rila shari shari.
# 12. Mima mim nik ni na.
# 13. Rano rano shiri shiri.
# 14. Shira shira melu melu.
# 15. Murel murel niran niran.
# 16. Lura lura shala shala.
